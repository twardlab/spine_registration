# %%
import os

# %%
# fname_I = '/home/dtward/Documents/UCLA/dong/spine_registration_2025/interpolated_atlas.npz'
# fname_L = '/home/dtward/Documents/UCLA/dong/spine_registration_2025/interpolated_atlas_labels.npz'
# fname_J = '/home/dtward/Documents/UCLA/dong/spine_registration_2025/Spine_Reflection.npz'
# pointsJ_file = '/qnap/Spine_Registration/spine4_image_with_reflection/Spine_4_Morphh_Central_Canal.swc'

fname_I = '/nafs/dtward/spine_work/interpolated_atlas.npz'
fname_L = '/nafs/dtward/spine_work/interpolated_atlas_labels.npz'
fname_J = '/nafs/dtward/spine_work/Spine_Reflection.npz'
pointsJ_file = '/nafs/dtward/spine_work/Spine_4_Morphh_Central_Canal.swc'

fname_script = '/home/abenneck/Desktop/spine_registration/spine_reg_pipeline.py'
outdir = '/home/abenneck/Desktop/spine_outputs'
e_path = '/home/abenneck/Desktop/emlddmm'
command_str = f'python3 {fname_script} {fname_I} {fname_L} {fname_J} {pointsJ_file} {outdir} {e_path} -niter 5 -v'

if True:
    os.system(command_str)
# Out:
# Successfully loaded atlas file . . .
# Successfully loaded atlas labels file . . .
# Successfully loaded target image data and axes files . . .
# Successfully loaded target image points file . . .
# xv:  <class 'list'>
# xv.shape:  3
# xv.shape:  [torch.Size([319]), torch.Size([29]), torch.Size([38])]
# v:  <class 'torch.Tensor'>
# v.shape:  torch.Size([5, 319, 29, 38, 3])
# Jd.shape:  torch.Size([1, 13, 46, 469])
# xv:  <class 'list'>
# xv.shape:  3
# xv.shape:  [torch.Size([319]), torch.Size([29]), torch.Size([38])]
# v:  <class 'torch.Tensor'>
# v.shape:  torch.Size([5, 319, 29, 38, 3])
# Jd.shape:  torch.Size([1, 13, 46, 469])
# xv:  <class 'list'>
# xv.shape:  3
# xv.shape:  [torch.Size([319]), torch.Size([29]), torch.Size([38])]
# v:  <class 'torch.Tensor'>
# v.shape:  torch.Size([5, 319, 29, 38, 3])
# Jd.shape:  torch.Size([1, 13, 46, 469])
# xv:  <class 'list'>
# xv.shape:  3
# xv.shape:  [torch.Size([319]), torch.Size([29]), torch.Size([38])]
# v:  <class 'torch.Tensor'>
# v.shape:  torch.Size([5, 319, 29, 38, 3])
# Jd.shape:  torch.Size([1, 13, 46, 469])
# xv:  <class 'list'>
# xv.shape:  3
# xv.shape:  [torch.Size([319]), torch.Size([29]), torch.Size([38])]
# v:  <class 'torch.Tensor'>
# v.shape:  torch.Size([5, 319, 29, 38, 3])
# Jd.shape:  torch.Size([1, 13, 46, 469])
# Traceback (most recent call last):
#   File "/home/abenneck/Desktop/spine_registration/spine_reg_pipeline.py", line 855, in <module>
#     main()
#   File "/home/abenneck/Desktop/spine_registration/spine_reg_pipeline.py", line 824, in main
#     ax[1].cla()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py", line 1400, in cla
#     self.clear()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py", line 1391, in clear
#     self.__clear()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py", line 1274, in __clear
#     axis.clear()  # Also resets the scale to linear.
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 906, in clear
#     self.reset_ticks()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 928, in reset_ticks
#     self.set_clip_path(self.axes.patch)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py", line 300, in wrapper
#     return func(*args, **kwargs)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 1137, in set_clip_path
#     for child in self.majorTicks + self.minorTicks:
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 572, in __get__
#     tick = instance._get_tick(major=True)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 1598, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 399, in __init__
#     data=([0], [0]), transform=ax.get_xaxis_transform("tick1"))
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py", line 933, in get_xaxis_transform
#     return self.spines.bottom.get_spine_transform()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/spines.py", line 341, in get_spine_transform
#     self._ensure_position_is_set()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/spines.py", line 206, in _ensure_position_is_set
#     self.set_position(self._position)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/spines.py", line 331, in set_position
#     self.axis.reset_ticks()
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 928, in reset_ticks
#     self.set_clip_path(self.axes.patch)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py", line 300, in wrapper
#     return func(*args, **kwargs)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 1137, in set_clip_path
#     for child in self.majorTicks + self.minorTicks:
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 572, in __get__
#     tick = instance._get_tick(major=True)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 1598, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/axis.py", line 402, in __init__
#     self.gridline.set(
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/artist.py", line 147, in <lambda>
#     cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/artist.py", line 1224, in set
#     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/artist.py", line 1216, in _internal_update
#     return self._update_props(
#   File "/home/abenneck/.local/lib/python3.10/site-packages/matplotlib/artist.py", line 1181, in _update_props
#     with cbook._setattr_cm(self, eventson=False):
#   File "/usr/lib/python3.10/contextlib.py", line 281, in helper
#     return _GeneratorContextManager(func, args, kwds)
#   File "/usr/lib/python3.10/contextlib.py", line 102, in __init__
#     def __init__(self, func, args, kwds):
# KeyboardInterrupt
